# %% [markdown]
# # INSTALL REQUIRED PACKAGES

# %%
# !pip install --quiet torch torchvision torchaudio
# !pip install --quiet transformers==4.45.0
# !pip install --quiet librosa
# !pip install --quiet soundfile
# !pip install --quiet accelerate
# !pip install -q huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 53.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 106.1 MB/s eta 0:00:00

# %% [markdown]
# # TEST FILE DOWNLOAD FROM HUGGINGFACE

# %%
from huggingface_hub import list_repo_files, hf_hub_download
import os
import shutil
repo_id = "bitwisemind/hackathon"
repo_type = "dataset"
download_dir = "./"

files = list_repo_files(repo_id=repo_id, repo_type=repo_type)
print(f"🔍 Found {len(files)} files in the repo.")

os.makedirs(download_dir, exist_ok=True)
downloaded_files = []

for file in files:
    file_path = hf_hub_download(repo_id=repo_id, filename=file, repo_type=repo_type)

    local_path = os.path.join(download_dir, file)
    os.makedirs(os.path.dirname(local_path), exist_ok=True)
    shutil.copy(file_path, local_path)

    downloaded_files.append(local_path)

print("✅ All files downloaded into:", download_dir)

# !unzip ./Test.zip
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 🔍 Found 5 files in the repo.
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# Test.zip:   0%|          | 0.00/63.0M [00:00<?, ?B/s]
# Train.zip:   0%|          | 0.00/289M [00:00<?, ?B/s]
# Train_annotation.zip:   0%|          | 0.00/58.5k [00:00<?, ?B/s]
# ✅ All files downloaded into: ./
# Archive:  ./Test.zip
#    creating: Test/
#   inflating: Test/test_001.wav
#   inflating: Test/test_002.wav
#   inflating: Test/test_003.wav
#   inflating: Test/test_004.wav
#   inflating: Test/test_005.wav
#   inflating: Test/test_006.wav
#   inflating: Test/test_007.wav
#   inflating: Test/test_008.wav
#   inflating: Test/test_009.wav
#   inflating: Test/test_010.wav
#   inflating: Test/test_011.wav
#   inflating: Test/test_012.wav
#   inflating: Test/test_013.wav
#   inflating: Test/test_014.wav
#   inflating: Test/test_015.wav
#   inflating: Test/test_016.wav
#   inflating: Test/test_017.wav
#   inflating: Test/test_018.wav
#   inflating: Test/test_019.wav
#   inflating: Test/test_020.wav
#   inflating: Test/test_021.wav
#   inflating: Test/test_022.wav
#   inflating: Test/test_023.wav
#   inflating: Test/test_024.wav
#   inflating: Test/test_025.wav
#   inflating: Test/test_026.wav
#   inflating: Test/test_027.wav
#   inflating: Test/test_028.wav
#   inflating: Test/test_029.wav
#   inflating: Test/test_030.wav
#   inflating: Test/test_031.wav
#   inflating: Test/test_032.wav
#   inflating: Test/test_033.wav
#   inflating: Test/test_034.wav
#   inflating: Test/test_035.wav
#   inflating: Test/test_036.wav
#   inflating: Test/test_037.wav
#   inflating: Test/test_038.wav
#   inflating: Test/test_039.wav
#   inflating: Test/test_040.wav
#   inflating: Test/test_041.wav
#   inflating: Test/test_042.wav
#   inflating: Test/test_043.wav
#   inflating: Test/test_044.wav
#   inflating: Test/test_045.wav
#   inflating: Test/test_046.wav
#   inflating: Test/test_047.wav
#   inflating: Test/test_048.wav
#   inflating: Test/test_049.wav
#   inflating: Test/test_050.wav
#   inflating: Test/test_051.wav
#   inflating: Test/test_052.wav
#   inflating: Test/test_053.wav
#   inflating: Test/test_054.wav
#   inflating: Test/test_055.wav
#   inflating: Test/test_056.wav
#   inflating: Test/test_057.wav
#   inflating: Test/test_058.wav
#   inflating: Test/test_059.wav
#   inflating: Test/test_060.wav
#   inflating: Test/test_061.wav
#   inflating: Test/test_062.wav
#   inflating: Test/test_063.wav
#   inflating: Test/test_064.wav
#   inflating: Test/test_065.wav
#   inflating: Test/test_066.wav
#   inflating: Test/test_067.wav
#   inflating: Test/test_068.wav
#   inflating: Test/test_069.wav
#   inflating: Test/test_070.wav
#   inflating: Test/test_071.wav
#   inflating: Test/test_072.wav
#   inflating: Test/test_073.wav
#   inflating: Test/test_074.wav
#   inflating: Test/test_075.wav
#   inflating: Test/test_076.wav
#   inflating: Test/test_077.wav
#   inflating: Test/test_078.wav
#   inflating: Test/test_079.wav
#   inflating: Test/test_080.wav
#   inflating: Test/test_081.wav
#   inflating: Test/test_082.wav
#   inflating: Test/test_083.wav
#   inflating: Test/test_084.wav
#   inflating: Test/test_085.wav
#   inflating: Test/test_086.wav
#   inflating: Test/test_087.wav
#   inflating: Test/test_088.wav
#   inflating: Test/test_089.wav
#   inflating: Test/test_090.wav
#   inflating: Test/test_091.wav
#   inflating: Test/test_092.wav
#   inflating: Test/test_093.wav
#   inflating: Test/test_094.wav
#   inflating: Test/test_095.wav
#   inflating: Test/test_096.wav
#   inflating: Test/test_097.wav
#   inflating: Test/test_098.wav
#   inflating: Test/test_099.wav
#   inflating: Test/test_100.wav
#   inflating: Test/test_101.wav
#   inflating: Test/test_102.wav
#   inflating: Test/test_103.wav
#   inflating: Test/test_104.wav
#   inflating: Test/test_105.wav
#   inflating: Test/test_106.wav
#   inflating: Test/test_107.wav
#   inflating: Test/test_108.wav
#   inflating: Test/test_109.wav
#   inflating: Test/test_110.wav
#   inflating: Test/test_111.wav
#   inflating: Test/test_112.wav
#   inflating: Test/test_113.wav
#   inflating: Test/test_114.wav
#   inflating: Test/test_115.wav
#   inflating: Test/test_116.wav
#   inflating: Test/test_117.wav
#   inflating: Test/test_118.wav
#   inflating: Test/test_119.wav
#   inflating: Test/test_120.wav
#   inflating: Test/test_121.wav
#   inflating: Test/test_122.wav
#   inflating: Test/test_123.wav
#   inflating: Test/test_124.wav
#   inflating: Test/test_125.wav
#   inflating: Test/test_126.wav
#   inflating: Test/test_127.wav
#   inflating: Test/test_128.wav
#   inflating: Test/test_129.wav
#   inflating: Test/test_130.wav
#   inflating: Test/test_131.wav
#   inflating: Test/test_132.wav
#   inflating: Test/test_133.wav
#   inflating: Test/test_134.wav
#   inflating: Test/test_135.wav
#   inflating: Test/test_136.wav
#   inflating: Test/test_137.wav
#   inflating: Test/test_138.wav
#   inflating: Test/test_139.wav
#   inflating: Test/test_140.wav
#   inflating: Test/test_141.wav
#   inflating: Test/test_142.wav
#   inflating: Test/test_143.wav
#   inflating: Test/test_144.wav
#   inflating: Test/test_145.wav
#   inflating: Test/test_146.wav
#   inflating: Test/test_147.wav
#   inflating: Test/test_148.wav
#   inflating: Test/test_149.wav
#   inflating: Test/test_150.wav
#   inflating: Test/test_151.wav
#   inflating: Test/test_152.wav
#   inflating: Test/test_153.wav
#   inflating: Test/test_154.wav
#   inflating: Test/test_155.wav
#   inflating: Test/test_156.wav
#   inflating: Test/test_157.wav
#   inflating: Test/test_158.wav
#   inflating: Test/test_159.wav
#   inflating: Test/test_160.wav
#   inflating: Test/test_161.wav
#   inflating: Test/test_162.wav
#   inflating: Test/test_163.wav
#   inflating: Test/test_164.wav
#   inflating: Test/test_165.wav
#   inflating: Test/test_166.wav
#   inflating: Test/test_167.wav
#   inflating: Test/test_168.wav
#   inflating: Test/test_169.wav
#   inflating: Test/test_170.wav
#   inflating: Test/test_171.wav
#   inflating: Test/test_172.wav
#   inflating: Test/test_173.wav
#   inflating: Test/test_174.wav
#   inflating: Test/test_175.wav
#   inflating: Test/test_176.wav
#   inflating: Test/test_177.wav
#   inflating: Test/test_178.wav
#   inflating: Test/test_179.wav
#   inflating: Test/test_180.wav
#   inflating: Test/test_181.wav
#   inflating: Test/test_182.wav
#   inflating: Test/test_183.wav
#   inflating: Test/test_184.wav
#   inflating: Test/test_185.wav
#   inflating: Test/test_186.wav
#   inflating: Test/test_187.wav
#   inflating: Test/test_188.wav
#   inflating: Test/test_189.wav
#   inflating: Test/test_190.wav
#   inflating: Test/test_191.wav
#   inflating: Test/test_192.wav
#   inflating: Test/test_193.wav
#   inflating: Test/test_194.wav
#   inflating: Test/test_195.wav
#   inflating: Test/test_196.wav
#   inflating: Test/test_197.wav
#   inflating: Test/test_198.wav
#   inflating: Test/test_199.wav
#   inflating: Test/test_200.wav
#   inflating: Test/test_201.wav
#   inflating: Test/test_202.wav
#   inflating: Test/test_203.wav
#   inflating: Test/test_204.wav
#   inflating: Test/test_205.wav
#   inflating: Test/test_206.wav
#   inflating: Test/test_207.wav
#   inflating: Test/test_208.wav
#   inflating: Test/test_209.wav
#   inflating: Test/test_210.wav
#   inflating: Test/test_211.wav
#   inflating: Test/test_212.wav
#   inflating: Test/test_213.wav
#   inflating: Test/test_214.wav
#   inflating: Test/test_215.wav
#   inflating: Test/test_216.wav
#   inflating: Test/test_217.wav
#   inflating: Test/test_218.wav
#   inflating: Test/test_219.wav
#   inflating: Test/test_220.wav
#   inflating: Test/test_221.wav
#   inflating: Test/test_222.wav
#   inflating: Test/test_223.wav
#   inflating: Test/test_224.wav
#   inflating: Test/test_225.wav
#   inflating: Test/test_226.wav
#   inflating: Test/test_227.wav
#   inflating: Test/test_228.wav
#   inflating: Test/test_229.wav
#   inflating: Test/test_230.wav
#   inflating: Test/test_231.wav
#   inflating: Test/test_232.wav
#   inflating: Test/test_233.wav
#   inflating: Test/test_234.wav
#   inflating: Test/test_235.wav
#   inflating: Test/test_236.wav
#   inflating: Test/test_237.wav
#   inflating: Test/test_238.wav
#   inflating: Test/test_239.wav
#   inflating: Test/test_240.wav
#   inflating: Test/test_241.wav
#   inflating: Test/test_242.wav
#   inflating: Test/test_243.wav
#   inflating: Test/test_244.wav
#   inflating: Test/test_245.wav
#   inflating: Test/test_246.wav
#   inflating: Test/test_247.wav
#   inflating: Test/test_248.wav
#   inflating: Test/test_249.wav
#   inflating: Test/test_250.wav
#   inflating: Test/test_251.wav
#   inflating: Test/test_252.wav
#   inflating: Test/test_253.wav
#   inflating: Test/test_254.wav
#   inflating: Test/test_255.wav
#   inflating: Test/test_256.wav
#   inflating: Test/test_257.wav
#   inflating: Test/test_258.wav
#   inflating: Test/test_259.wav
#   inflating: Test/test_260.wav
#   inflating: Test/test_261.wav
#   inflating: Test/test_262.wav
#   inflating: Test/test_263.wav
#   inflating: Test/test_264.wav
#   inflating: Test/test_265.wav
#   inflating: Test/test_266.wav
#   inflating: Test/test_267.wav
#   inflating: Test/test_268.wav
#   inflating: Test/test_269.wav
#   inflating: Test/test_270.wav
#   inflating: Test/test_271.wav
#   inflating: Test/test_272.wav
#   inflating: Test/test_273.wav
#   inflating: Test/test_274.wav
#   inflating: Test/test_275.wav
#   inflating: Test/test_276.wav
#   inflating: Test/test_277.wav
#   inflating: Test/test_278.wav
#   inflating: Test/test_279.wav
#   inflating: Test/test_280.wav
#   inflating: Test/test_281.wav
#   inflating: Test/test_282.wav
#   inflating: Test/test_283.wav
#   inflating: Test/test_284.wav
#   inflating: Test/test_285.wav
#   inflating: Test/test_286.wav
#   inflating: Test/test_287.wav
#   inflating: Test/test_288.wav
#   inflating: Test/test_289.wav
#   inflating: Test/test_290.wav
#   inflating: Test/test_291.wav
#   inflating: Test/test_292.wav
#   inflating: Test/test_293.wav
#   inflating: Test/test_294.wav
#   inflating: Test/test_295.wav
#   inflating: Test/test_296.wav
#   inflating: Test/test_297.wav
#   inflating: Test/test_298.wav
#   inflating: Test/test_299.wav
#   inflating: Test/test_300.wav
#   inflating: Test/test_301.wav
#   inflating: Test/test_302.wav
#   inflating: Test/test_303.wav
#   inflating: Test/test_304.wav
#   inflating: Test/test_305.wav
#   inflating: Test/test_306.wav
#   inflating: Test/test_307.wav
#   inflating: Test/test_308.wav
#   inflating: Test/test_309.wav
#   inflating: Test/test_310.wav
#   inflating: Test/test_311.wav
#   inflating: Test/test_312.wav
#   inflating: Test/test_313.wav
#   inflating: Test/test_314.wav
#   inflating: Test/test_315.wav
#   inflating: Test/test_316.wav
#   inflating: Test/test_317.wav
#   inflating: Test/test_318.wav
#   inflating: Test/test_319.wav
#   inflating: Test/test_320.wav
#   inflating: Test/test_321.wav
#   inflating: Test/test_322.wav
#   inflating: Test/test_323.wav
#   inflating: Test/test_324.wav
#   inflating: Test/test_325.wav
#   inflating: Test/test_326.wav
#   inflating: Test/test_327.wav
#   inflating: Test/test_328.wav
#   inflating: Test/test_329.wav
#   inflating: Test/test_330.wav
#   inflating: Test/test_331.wav
#   inflating: Test/test_332.wav
#   inflating: Test/test_333.wav
#   inflating: Test/test_334.wav
#   inflating: Test/test_335.wav
#   inflating: Test/test_336.wav
#   inflating: Test/test_337.wav
#   inflating: Test/test_338.wav
#   inflating: Test/test_339.wav
#   inflating: Test/test_340.wav
#   inflating: Test/test_341.wav
#   inflating: Test/test_342.wav
#   inflating: Test/test_343.wav
#   inflating: Test/test_344.wav
#   inflating: Test/test_345.wav
#   inflating: Test/test_346.wav
#   inflating: Test/test_347.wav
#   inflating: Test/test_348.wav
#   inflating: Test/test_349.wav
#   inflating: Test/test_350.wav
#   inflating: Test/test_351.wav
#   inflating: Test/test_352.wav
#   inflating: Test/test_353.wav
#   inflating: Test/test_354.wav
#   inflating: Test/test_355.wav
#   inflating: Test/test_356.wav
#   inflating: Test/test_357.wav
#   inflating: Test/test_358.wav
#   inflating: Test/test_359.wav
#   inflating: Test/test_360.wav
#   inflating: Test/test_361.wav
#   inflating: Test/test_362.wav
#   inflating: Test/test_363.wav
#   inflating: Test/test_364.wav
#   inflating: Test/test_365.wav
#   inflating: Test/test_366.wav
#   inflating: Test/test_367.wav
#   inflating: Test/test_368.wav
#   inflating: Test/test_369.wav
#   inflating: Test/test_370.wav
#   inflating: Test/test_371.wav
#   inflating: Test/test_372.wav
#   inflating: Test/test_373.wav
#   inflating: Test/test_374.wav
#   inflating: Test/test_375.wav
#   inflating: Test/test_376.wav
#   inflating: Test/test_377.wav
#   inflating: Test/test_378.wav
#   inflating: Test/test_379.wav
#   inflating: Test/test_380.wav
#   inflating: Test/test_381.wav
#   inflating: Test/test_382.wav
#   inflating: Test/test_383.wav
#   inflating: Test/test_384.wav
#   inflating: Test/test_385.wav
#   inflating: Test/test_386.wav
#   inflating: Test/test_387.wav
#   inflating: Test/test_388.wav
#   inflating: Test/test_389.wav
#   inflating: Test/test_390.wav
#   inflating: Test/test_391.wav
#   inflating: Test/test_392.wav
#   inflating: Test/test_393.wav
#   inflating: Test/test_394.wav
#   inflating: Test/test_395.wav
#   inflating: Test/test_396.wav
#   inflating: Test/test_397.wav
#   inflating: Test/test_398.wav
#   inflating: Test/test_399.wav
#   inflating: Test/test_400.wav
#   inflating: Test/test_401.wav
#   inflating: Test/test_402.wav
#   inflating: Test/test_403.wav
#   inflating: Test/test_404.wav
#   inflating: Test/test_405.wav
#   inflating: Test/test_406.wav
#   inflating: Test/test_407.wav
#   inflating: Test/test_408.wav
#   inflating: Test/test_409.wav
#   inflating: Test/test_410.wav
#   inflating: Test/test_411.wav
#   inflating: Test/test_412.wav
#   inflating: Test/test_413.wav
#   inflating: Test/test_414.wav
#   inflating: Test/test_415.wav
#   inflating: Test/test_416.wav
#   inflating: Test/test_417.wav
#   inflating: Test/test_418.wav
#   inflating: Test/test_419.wav
#   inflating: Test/test_420.wav
#   inflating: Test/test_421.wav
#   inflating: Test/test_422.wav
#   inflating: Test/test_423.wav
#   inflating: Test/test_424.wav
#   inflating: Test/test_425.wav
#   inflating: Test/test_426.wav
#   inflating: Test/test_427.wav
#   inflating: Test/test_428.wav
#   inflating: Test/test_429.wav
#   inflating: Test/test_430.wav
#   inflating: Test/test_431.wav
#   inflating: Test/test_432.wav
#   inflating: Test/test_433.wav
#   inflating: Test/test_434.wav
#   inflating: Test/test_435.wav
#   inflating: Test/test_436.wav
#   inflating: Test/test_437.wav
#   inflating: Test/test_438.wav
#   inflating: Test/test_439.wav
#   inflating: Test/test_440.wav
#   inflating: Test/test_441.wav
#   inflating: Test/test_442.wav
#   inflating: Test/test_443.wav
#   inflating: Test/test_444.wav
#   inflating: Test/test_445.wav
#   inflating: Test/test_446.wav
#   inflating: Test/test_447.wav
#   inflating: Test/test_448.wav
#   inflating: Test/test_449.wav
#   inflating: Test/test_450.wav

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import os
import time
import pandas as pd
import torch
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import librosa
from tqdm import tqdm
import warnings
import gc
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully!")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ✅ Libraries imported successfully!

# %% [markdown]
# # SYSTEM CONFIGURATION CHECK

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"\n{'='*60}")
print(f"SYSTEM CONFIGURATION")
print(f"{'='*60}")
print(f"Device: {device.upper()}")

if device == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("⚠️ Warning: Running on CPU. Inference will be slower.")
# Out:
# ============================================================
# SYSTEM CONFIGURATION
# ============================================================
# Device: CUDA
# GPU: Tesla T4
# Memory: 14.74 GB

# %% [markdown]
# # DEFINE PATHS AND CONFIGURATION

# %%
MODEL_NAME = "bitwisemind/bitwisemind-whisper-medium-bangla"
TEST_AUDIO_PATH = "./Test"
OUTPUT_CSV_PATH = "bitwisemind_predictions_hidden.csv"

print(f"\n{'='*60}")
print(f"CONFIGURATION")
print(f"{'='*60}")
print(f"Model: {MODEL_NAME}")
print(f"Input Path: {TEST_AUDIO_PATH}")
print(f"Output CSV: {OUTPUT_CSV_PATH}")
# Out:
# ============================================================
# CONFIGURATION
# ============================================================
# Model: bitwisemind/bitwisemind-whisper-medium-bangla
# Input Path: ./Test
# Output CSV: bitwisemind_predictions_hidden.csv

# %% [markdown]
# # LOAD MODEL AND PROCESSOR

# %%
print(f"\n{'='*60}")
print(f"LOADING MODEL")
print(f"{'='*60}")

# Start timing for model loading
model_load_start = time.time()

try:
    # Clear cache before loading
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    print(f"📦 Loading model from HuggingFace Hub...")
    print(f"   (First run will download model, subsequent runs use cache)")

    # Load processor and model
    processor = WhisperProcessor.from_pretrained(MODEL_NAME)
    model = WhisperForConditionalGeneration.from_pretrained(
        MODEL_NAME,
        low_cpu_mem_usage=True
    )

    # Remove language/task forcing
    if hasattr(model.generation_config, 'language'):
        delattr(model.generation_config, 'language')
    if hasattr(model.generation_config, 'task'):
        delattr(model.generation_config, 'task')
    model.generation_config.forced_decoder_ids = None

    # Move to device and set to eval mode
    model.to(device)
    model.eval()

    model_load_end = time.time()
    model_load_time = model_load_end - model_load_start

    print(f"✅ Model loaded successfully!")
    print(f"⏱️ Model loading time: {model_load_time:.2f} seconds")

    # Clear cache after loading
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

except Exception as e:
    print(f"❌ Error loading model: {e}")
    raise
# Out:
# ============================================================
# LOADING MODEL
# ============================================================
# 📦 Loading model from HuggingFace Hub...
#    (First run will download model, subsequent runs use cache)
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/223 [00:00<?, ?B/s]
# ✅ Model loaded successfully!
# ⏱️ Model loading time: 47.33 seconds

# %% [markdown]
# # SCAN AUDIO FILES

# %%
print(f"\n{'='*60}")
print(f"SCANNING AUDIO FILES")
print(f"{'='*60}")

audio_files = []
if os.path.exists(TEST_AUDIO_PATH):
    all_files = sorted(os.listdir(TEST_AUDIO_PATH))
    audio_files = [f for f in all_files if f.lower().endswith('.wav')]

    if len(audio_files) > 0:
        print(f"✅ Found {len(audio_files)} audio files")
        print(f"   First: {audio_files[0]}")
        print(f"   Last: {audio_files[-1]}")
    else:
        print("⚠️ No .wav files found in the test folder")
        print("   Please ensure your audio files have .wav extension")
else:
    print(f"❌ Error: Test folder not found at {TEST_AUDIO_PATH}")
    raise FileNotFoundError(f"Directory {TEST_AUDIO_PATH} does not exist")
# Out:
# ============================================================
# SCANNING AUDIO FILES
# ============================================================
# ✅ Found 450 audio files
#    First: test_001.wav
#    Last: test_450.wav

# %% [markdown]
# # DEFINE TRANSCRIPTION FUNCTION

# %%
def transcribe_audio(audio_path, processor, model, device):
    """
    Transcribe a single audio file using the fine-tuned Whisper model.

    Args:
        audio_path: Path to the audio file
        processor: Whisper processor
        model: Fine-tuned Whisper model
        device: Device to run inference on

    Returns:
        Transcription text
    """
    try:
        # Load and preprocess audio
        audio_array, sampling_rate = librosa.load(audio_path, sr=16000)
        input_features = processor(
            audio_array,
            sampling_rate=16000,
            return_tensors="pt"
        ).input_features.to(device)

        # Generate transcription
        with torch.no_grad():
            predicted_ids = model.generate(
                input_features,
                max_length=225,
                num_beams=5,
            )

        # Decode transcription
        transcription = processor.batch_decode(
            predicted_ids,
            skip_special_tokens=True
        )[0]

        return transcription.strip()

    except Exception as e:
        print(f"   ⚠️ Error: {os.path.basename(audio_path)} - {str(e)}")
        return ""

# %% [markdown]
# # PROCESS ALL AUDIO FILES (INFERENCE)

# %%
print(f"\n{'='*60}")
print(f"INFERENCE STARTED")
print(f"{'='*60}")

results = []
failed_count = 0

# Start timing inference only
inference_start = time.time()

# Process each audio file with tqdm progress bar
with tqdm(total=len(audio_files), desc="Transcribing", unit="file", ncols=100,
          bar_format='{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]') as pbar:

    for idx, audio_file in enumerate(audio_files):
        audio_path = os.path.join(TEST_AUDIO_PATH, audio_file)

        # Validate file
        if not os.path.exists(audio_path) or os.path.getsize(audio_path) == 0:
            failed_count += 1
            pbar.update(1)
            continue

        # Transcribe audio
        transcription = transcribe_audio(audio_path, processor, model, device)

        # Store result
        results.append({
            "audio": audio_file,
            "text": transcription
        })

        # Update progress bar
        pbar.update(1)

        # Periodic memory cleanup (every 50 files)
        if (idx + 1) % 50 == 0:
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

# End timing
inference_end = time.time()
inference_time = inference_end - inference_start

# Final memory cleanup
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

print(f"\n{'='*60}")
print(f"INFERENCE COMPLETED")
print(f"{'='*60}")
print(f"✅ Successfully transcribed: {len(results)} files")
print(f"⏱️ Total Inference Time: {inference_time:.2f} seconds ({inference_time/60:.2f} minutes)")
if len(results) > 0:
    print(f"⚡ Average time per file: {inference_time/len(results):.2f} seconds")
if failed_count > 0:
    print(f"⚠️ Failed/Skipped: {failed_count} files")
# Out:
# ============================================================
# INFERENCE STARTED
# ============================================================
# Transcribing:   0%|                                                                | 0/450 [00:00<?]The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Transcribing: 100%|██████████████████████████████████████████████████████████| 450/450 [16:37<00:00]
# ============================================================
# INFERENCE COMPLETED
# ============================================================
# ✅ Successfully transcribed: 450 files
# ⏱️ Total Inference Time: 997.21 seconds (16.62 minutes)
# ⚡ Average time per file: 2.22 seconds

# %% [markdown]
# # SAVE RESULTS TO CSV

# %%
print(f"\n{'='*60}")
print(f"SAVING RESULTS")
print(f"{'='*60}")

if len(results) == 0:
    print("❌ No transcriptions generated.")
    print("   Please check your audio files and model configuration.")
else:
    df = pd.DataFrame(results)
    df = df[["audio", "text"]]

    # Save to CSV
    df.to_csv(OUTPUT_CSV_PATH, index=False, encoding='utf-8-sig')

    print(f"✅ CSV file saved: {OUTPUT_CSV_PATH}")
    print(f"   Total records: {len(df)}")
    print(f"   Columns: {', '.join(df.columns)}")
# Out:
# ============================================================
# SAVING RESULTS
# ============================================================
# ✅ CSV file saved: bitwisemind_predictions_hidden.csv
#    Total records: 450
#    Columns: audio, text

# %% [markdown]
# # DISPLAY STATISTICS

# %%
if len(results) > 0:
    print(f"\n{'='*60}")
    print(f"STATISTICS")
    print(f"{'='*60}")

    empty_count = df['text'].isna().sum() + (df['text'] == '').sum()
    valid_count = len(df) - empty_count

    print(f"Total files processed: {len(df)}")
    print(f"Valid transcriptions: {valid_count}")
    print(f"Empty transcriptions: {empty_count}")

    if valid_count > 0:
        valid_df = df[df['text'].str.len() > 0]
        avg_len = valid_df['text'].str.len().mean()
        min_len = valid_df['text'].str.len().min()
        max_len = valid_df['text'].str.len().max()

        print(f"\nTranscription length:")
        print(f"   Average: {avg_len:.0f} characters")
        print(f"   Range: {min_len} - {max_len} characters")
# Out:
# ============================================================
# STATISTICS
# ============================================================
# Total files processed: 450
# Valid transcriptions: 450
# Empty transcriptions: 0
#
# Transcription length:
#    Average: 29 characters
#    Range: 15 - 65 characters

# %% [markdown]
# # DISPLAY SAMPLE TRANSCRIPTIONS

# %%
if len(results) > 0:
    print(f"\n{'='*60}")
    print(f"SAMPLE TRANSCRIPTIONS")
    print(f"{'='*60}")

    # Show first 3 transcriptions
    for idx, row in df.head(3).iterrows():
        print(f"\n{idx+1}. {row['audio']}")
        text_preview = row['text'][:100] + '...' if len(row['text']) > 100 else row['text']
        print(f"   {text_preview}")
# Out:
# ============================================================
# SAMPLE TRANSCRIPTIONS
# ============================================================
#
# 1. test_001.wav
#    তুমি কি খেলতে যাচ্ছো?
#
# 2. test_002.wav
#    তুমি কি আমাকে কলমটা দেবে?
#
# 3. test_003.wav
#    আজ দুপুরে রাস্তায় পানি জমেছিল।
